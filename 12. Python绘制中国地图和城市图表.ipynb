# %% [markdown]
# ## Python绘制中国地图和城市图表

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

# %% [markdown]
# ### 1. 绘制中国城市数据图表

# %%
# 2019全国各省人口数量排名，单位万，前10个
province_population = [
    ["广东", 11169],
    ["山东", 10005.83],
    ["河南", 9559.13],
    ["四川", 8302],
    ["江苏", 8029.3],
    ["河北", 7519.52],
    ["湖南", 6860.2],
    ["安徽", 6254.8],
    ["湖北", 5902],
    ["浙江", 5657]
]

# %%
map = (
    Map()
    .add("各省人口数量", province_population, "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="2019全国各省人口数量排名"),
        visualmap_opts=opts.VisualMapOpts(max_=12000),
    )
)
map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="ff6f5119689548d1a67a90c16778d45e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_ff6f5119689548d1a67a90c16778d45e = echarts.init(
#                     document.getElementById('ff6f5119689548d1a67a90c16778d45e'), 'white', {renderer: 'canvas'});
#                 var option_ff6f5119689548d1a67a90c16778d45e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5404\u7701\u4eba\u53e3\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 11169
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 10005.83
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 9559.13
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 8302
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 8029.3
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 7519.52
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 6860.2
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 6254.8
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 5902
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 5657
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u7701\u4eba\u53e3\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u5404\u7701\u4eba\u53e3\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "2019\u5168\u56fd\u5404\u7701\u4eba\u53e3\u6570\u91cf\u6392\u540d",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 12000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_ff6f5119689548d1a67a90c16778d45e.setOption(option_ff6f5119689548d1a67a90c16778d45e);
#         });
#     </script>

# %% [markdown]
# ### 2. 绘制具体城市数据

# %%
# 2019年北京各区人口数量，前7个
beijing_district = [
    ["朝阳区", 395.5],
    ["海淀区", 369.4],
    ["丰台区", 232.4],
    ["昌平区", 196.3],
    ["大兴区", 156.2],
    ["通州区", 137.8],
    ["西城区", 129.8],
]

# %%
map = (
    Map()
    .add("各区人口", beijing_district, "北京")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="2019年北京各区人口数量"), 
        visualmap_opts=opts.VisualMapOpts(max_=400)
    )
)
map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '北京':'https://assets.pyecharts.org/assets/maps/beijing'
#         }
#     });
# </script>
#
#         <div id="72953c8499fa4ca2a454561b8bb19df0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '北京'], function(echarts) {
#                 var chart_72953c8499fa4ca2a454561b8bb19df0 = echarts.init(
#                     document.getElementById('72953c8499fa4ca2a454561b8bb19df0'), 'white', {renderer: 'canvas'});
#                 var option_72953c8499fa4ca2a454561b8bb19df0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5404\u533a\u4eba\u53e3",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u5317\u4eac",
#             "data": [
#                 {
#                     "name": "\u671d\u9633\u533a",
#                     "value": 395.5
#                 },
#                 {
#                     "name": "\u6d77\u6dc0\u533a",
#                     "value": 369.4
#                 },
#                 {
#                     "name": "\u4e30\u53f0\u533a",
#                     "value": 232.4
#                 },
#                 {
#                     "name": "\u660c\u5e73\u533a",
#                     "value": 196.3
#                 },
#                 {
#                     "name": "\u5927\u5174\u533a",
#                     "value": 156.2
#                 },
#                 {
#                     "name": "\u901a\u5dde\u533a",
#                     "value": 137.8
#                 },
#                 {
#                     "name": "\u897f\u57ce\u533a",
#                     "value": 129.8
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u533a\u4eba\u53e3"
#             ],
#             "selected": {
#                 "\u5404\u533a\u4eba\u53e3": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "2019\u5e74\u5317\u4eac\u5404\u533a\u4eba\u53e3\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 400,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_72953c8499fa4ca2a454561b8bb19df0.setOption(option_72953c8499fa4ca2a454561b8bb19df0);
#         });
#     </script>

# %% [markdown]
# ## Python绘制漏斗图

# %% [markdown]
# 漏斗图适用于业务流程比较规范、周期长、环节多的流程分析，通过漏斗各环节业务数据的比较，能够直观地发现和说明问题所在

# %% [markdown]
# ### 1. 读取数据

# %%
import pandas as pd

# %%
df_home_page = pd.read_csv("./datas/ecommerce-website-funnel-analysis/home_page_table.csv")
df_search_page = pd.read_csv("./datas/ecommerce-website-funnel-analysis/search_page_table.csv")
df_payment_page = pd.read_csv("./datas/ecommerce-website-funnel-analysis/payment_page_table.csv")
df_payment_confirmation_page = pd.read_csv("./datas/ecommerce-website-funnel-analysis/payment_confirmation_table.csv")
df_user_table = pd.read_csv("./datas/ecommerce-website-funnel-analysis/user_table.csv")

# %%
df_home_page.head(3)
# Out:
#    user_id       page
# 0   313593  home_page
# 1   468315  home_page
# 2   264005  home_page

# %%
df_search_page.head(3)
# Out:
#    user_id         page
# 0    15866  search_page
# 1   347058  search_page
# 2   577020  search_page

# %%
df_payment_page.head(3)
# Out:
#    user_id          page
# 0   253019  payment_page
# 1   310478  payment_page
# 2   304081  payment_page

# %%
df_payment_confirmation_page.head(3)
# Out:
#    user_id                       page
# 0   123100  payment_confirmation_page
# 1   704999  payment_confirmation_page
# 2   407188  payment_confirmation_page

# %%
df_user_table.head(3)
# Out:
#    user_id        date   device     sex
# 0   450007  2015-02-28  Desktop  Female
# 1   756838  2015-01-13  Desktop    Male
# 2   568983  2015-04-09  Desktop    Male

# %%
df_user_table.shape
# Out:
# (90400, 4)

# %%
df_user_table["device"].value_counts()
# Out:
# Desktop    60200
# Mobile     30200
# Name: device, dtype: int64

# %%
df_user_table["sex"].value_counts()
# Out:
# Male      45325
# Female    45075
# Name: sex, dtype: int64

# %% [markdown]
# ### 2. 绘制漏斗图

# %%
df_merge = pd.merge(
    left=df_home_page, 
    right=df_search_page, 
    left_on="user_id", 
    right_on="user_id", 
    how="left")
df_merge
# Out:
#        user_id     page_x       page_y
# 0       313593  home_page          NaN
# 1       468315  home_page          NaN
# 2       264005  home_page          NaN
# 3       290784  home_page          NaN
# 4       639104  home_page  search_page
# ...        ...        ...          ...
# 90395   456851  home_page          NaN
# 90396   128619  home_page  search_page
# 90397   167290  home_page          NaN
# 90398   437765  home_page          NaN
# 90399   337840  home_page          NaN
#
# [90400 rows x 3 columns]

# %%
df_merge = pd.merge(
    left=df_merge, 
    right=df_payment_page, 
    left_on="user_id", 
    right_on="user_id", 
    how="left")
df_merge
# Out:
#        user_id     page_x       page_y page
# 0       313593  home_page          NaN  NaN
# 1       468315  home_page          NaN  NaN
# 2       264005  home_page          NaN  NaN
# 3       290784  home_page          NaN  NaN
# 4       639104  home_page  search_page  NaN
# ...        ...        ...          ...  ...
# 90395   456851  home_page          NaN  NaN
# 90396   128619  home_page  search_page  NaN
# 90397   167290  home_page          NaN  NaN
# 90398   437765  home_page          NaN  NaN
# 90399   337840  home_page          NaN  NaN
#
# [90400 rows x 4 columns]

# %%
df_merge = pd.merge(
    left=df_merge, 
    right=df_payment_confirmation_page, 
    left_on="user_id", 
    right_on="user_id", 
    how="left")
df_merge
# Out:
#        user_id     page_x       page_y page_x page_y
# 0       313593  home_page          NaN    NaN    NaN
# 1       468315  home_page          NaN    NaN    NaN
# 2       264005  home_page          NaN    NaN    NaN
# 3       290784  home_page          NaN    NaN    NaN
# 4       639104  home_page  search_page    NaN    NaN
# ...        ...        ...          ...    ...    ...
# 90395   456851  home_page          NaN    NaN    NaN
# 90396   128619  home_page  search_page    NaN    NaN
# 90397   167290  home_page          NaN    NaN    NaN
# 90398   437765  home_page          NaN    NaN    NaN
# 90399   337840  home_page          NaN    NaN    NaN
#
# [90400 rows x 5 columns]

# %%
df_merge.columns = ["user_id", "home_page", "search_page", "payment_page", "confirmation_page"]
df_merge
# Out:
#        user_id  home_page  search_page payment_page confirmation_page
# 0       313593  home_page          NaN          NaN               NaN
# 1       468315  home_page          NaN          NaN               NaN
# 2       264005  home_page          NaN          NaN               NaN
# 3       290784  home_page          NaN          NaN               NaN
# 4       639104  home_page  search_page          NaN               NaN
# ...        ...        ...          ...          ...               ...
# 90395   456851  home_page          NaN          NaN               NaN
# 90396   128619  home_page  search_page          NaN               NaN
# 90397   167290  home_page          NaN          NaN               NaN
# 90398   437765  home_page          NaN          NaN               NaN
# 90399   337840  home_page          NaN          NaN               NaN
#
# [90400 rows x 5 columns]

# %%
datas = []
for column in df_merge.columns:
    if column == "user_id":
        continue
    datas.append([column, df_merge[column].dropna().size])
datas
# Out:
# [['home_page', 90400],
#  ['search_page', 45200],
#  ['payment_page', 6030],
#  ['confirmation_page', 452]]

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel

# %%
funnel = (
    Funnel()
    .add("转化", datas)
    .set_global_opts(title_opts=opts.TitleOpts(title="电商页面转化漏斗图"))
)
funnel.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d06fe71dda9d4ef5943237ab6395e8e2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d06fe71dda9d4ef5943237ab6395e8e2 = echarts.init(
#                     document.getElementById('d06fe71dda9d4ef5943237ab6395e8e2'), 'white', {renderer: 'canvas'});
#                 var option_d06fe71dda9d4ef5943237ab6395e8e2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u8f6c\u5316",
#             "data": [
#                 {
#                     "name": "home_page",
#                     "value": 90400
#                 },
#                 {
#                     "name": "search_page",
#                     "value": 45200
#                 },
#                 {
#                     "name": "payment_page",
#                     "value": 6030
#                 },
#                 {
#                     "name": "confirmation_page",
#                     "value": 452
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "search_page",
#                 "home_page",
#                 "confirmation_page",
#                 "payment_page"
#             ],
#             "selected": {
#                 "home_page": true,
#                 "search_page": true,
#                 "payment_page": true,
#                 "confirmation_page": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u7535\u5546\u9875\u9762\u8f6c\u5316\u6f0f\u6597\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d06fe71dda9d4ef5943237ab6395e8e2.setOption(option_d06fe71dda9d4ef5943237ab6395e8e2);
#         });
#     </script>

# %% [markdown]
# ### 3. 绘制分性别漏斗图

# %%
df_merge = pd.merge(
    left=df_merge, 
    right=df_user_table, 
    left_on="user_id", 
    right_on="user_id", 
    how="left")
df_merge
# Out:
#        user_id  home_page  search_page payment_page confirmation_page  \
# 0       313593  home_page          NaN          NaN               NaN
# 1       468315  home_page          NaN          NaN               NaN
# 2       264005  home_page          NaN          NaN               NaN
# 3       290784  home_page          NaN          NaN               NaN
# 4       639104  home_page  search_page          NaN               NaN
# ...        ...        ...          ...          ...               ...
# 90395   456851  home_page          NaN          NaN               NaN
# 90396   128619  home_page  search_page          NaN               NaN
# 90397   167290  home_page          NaN          NaN               NaN
# 90398   437765  home_page          NaN          NaN               NaN
# 90399   337840  home_page          NaN          NaN               NaN
#
#              date   device     sex
# 0      2015-02-26  Desktop  Female
# 1      2015-02-21  Desktop    Male
# 2      2015-03-25  Desktop  Female
# 3      2015-03-14  Desktop    Male
# 4      2015-01-03  Desktop  Female
# ...           ...      ...     ...
# 90395  2015-03-16   Mobile    Male
# 90396  2015-04-16  Desktop    Male
# 90397  2015-03-29  Desktop  Female
# 90398  2015-04-27  Desktop    Male
# 90399  2015-02-07  Desktop    Male
#
# [90400 rows x 8 columns]

# %%
df_man = df_merge[df_merge["device"]=="Desktop"]
datas = []

for column in ["home_page","search_page","payment_page","confirmation_page"]:
    datas.append([column, df_man[column].dropna().size])

funnel_man = (
    Funnel()
    .add("转化", datas)
    .set_global_opts(title_opts=opts.TitleOpts(title="电商页面转化漏斗图"))
)
funnel_man.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6c96fcdf4b9849edbf4cb55bd382b7c3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6c96fcdf4b9849edbf4cb55bd382b7c3 = echarts.init(
#                     document.getElementById('6c96fcdf4b9849edbf4cb55bd382b7c3'), 'white', {renderer: 'canvas'});
#                 var option_6c96fcdf4b9849edbf4cb55bd382b7c3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u8f6c\u5316",
#             "data": [
#                 {
#                     "name": "home_page",
#                     "value": 60200
#                 },
#                 {
#                     "name": "search_page",
#                     "value": 30100
#                 },
#                 {
#                     "name": "payment_page",
#                     "value": 3010
#                 },
#                 {
#                     "name": "confirmation_page",
#                     "value": 150
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "search_page",
#                 "home_page",
#                 "confirmation_page",
#                 "payment_page"
#             ],
#             "selected": {
#                 "home_page": true,
#                 "search_page": true,
#                 "payment_page": true,
#                 "confirmation_page": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u7535\u5546\u9875\u9762\u8f6c\u5316\u6f0f\u6597\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6c96fcdf4b9849edbf4cb55bd382b7c3.setOption(option_6c96fcdf4b9849edbf4cb55bd382b7c3);
#         });
#     </script>

# %%
df_feman = df_merge[df_merge["device"]=="Mobile"]
datas = []

for column in ["home_page","search_page","payment_page","confirmation_page"]:
    datas.append([column, df_feman[column].dropna().size])

funnel_feman = (
    Funnel()
    .add("转化", datas)
    .set_global_opts(title_opts=opts.TitleOpts(title="电商页面转化漏斗图"))
)
funnel_feman.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ff4da68454b2451985155f37e8ea6de2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ff4da68454b2451985155f37e8ea6de2 = echarts.init(
#                     document.getElementById('ff4da68454b2451985155f37e8ea6de2'), 'white', {renderer: 'canvas'});
#                 var option_ff4da68454b2451985155f37e8ea6de2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u8f6c\u5316",
#             "data": [
#                 {
#                     "name": "home_page",
#                     "value": 30200
#                 },
#                 {
#                     "name": "search_page",
#                     "value": 15100
#                 },
#                 {
#                     "name": "payment_page",
#                     "value": 3020
#                 },
#                 {
#                     "name": "confirmation_page",
#                     "value": 302
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "search_page",
#                 "home_page",
#                 "confirmation_page",
#                 "payment_page"
#             ],
#             "selected": {
#                 "home_page": true,
#                 "search_page": true,
#                 "payment_page": true,
#                 "confirmation_page": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u7535\u5546\u9875\u9762\u8f6c\u5316\u6f0f\u6597\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ff4da68454b2451985155f37e8ea6de2.setOption(option_ff4da68454b2451985155f37e8ea6de2);
#         });
#     </script>

# %%
datas
# Out:
# [['home_page', 45075],
#  ['search_page', 22676],
#  ['payment_page', 3100],
#  ['confirmation_page', 241]]

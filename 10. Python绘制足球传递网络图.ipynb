# %% [markdown]
# ## Python绘制足球传递网络图

# %% [markdown]
# ***网络图Graph***：
# * 由节点、边、权重所组成的数据关系图
# * 直观的展示事物节点间的复杂关系

# %%
import pandas as pd
from pyecharts import options as opts
from pyecharts.charts import Graph, Page

# %% [markdown]
# ### 1. 读取足球赛队员传球数据集

# %%
dataset = pd.read_csv('./datas/passingevents.csv')
dataset.head()
# Out:
#    MatchID     TeamID OriginPlayerID DestinationPlayerID MatchPeriod  \
# 0        1    Huskies     Huskies_D1          Huskies_F1          1H
# 1        1    Huskies     Huskies_M1          Huskies_F2          1H
# 2        1  Opponent1   Opponent1_D2        Opponent1_G1          1H
# 3        1  Opponent1   Opponent1_G1        Opponent1_F1          1H
# 4        1    Huskies     Huskies_M2          Huskies_M3          1H
#
#    EventTime EventSubType  EventOrigin_x  EventOrigin_y  EventDestination_x  \
# 0  46.323501    Head pass             34             97                59.0
# 1  51.022546  Simple pass             53             89                69.0
# 2  89.008721  Simple pass             19             16                 5.0
# 3  92.216160       Launch              5             50                67.0
# 4  98.265191  Simple pass             42             55                36.0
#
#    EventDestination_y
# 0                95.0
# 1                91.0
# 2                50.0
# 3                44.0
# 4                54.0

# %%
# 只取一个场次，一个队伍的数据
dataset = dataset[(dataset["MatchID"]==1) & (dataset["TeamID"]=='Huskies')]
dataset.head()
# Out:
#     MatchID   TeamID OriginPlayerID DestinationPlayerID MatchPeriod  \
# 0         1  Huskies     Huskies_D1          Huskies_F1          1H
# 1         1  Huskies     Huskies_M1          Huskies_F2          1H
# 4         1  Huskies     Huskies_M2          Huskies_M3          1H
# 8         1  Huskies     Huskies_D1          Huskies_F1          1H
# 11        1  Huskies     Huskies_D1          Huskies_G1          1H
#
#      EventTime EventSubType  EventOrigin_x  EventOrigin_y  EventDestination_x  \
# 0    46.323501    Head pass             34             97                59.0
# 1    51.022546  Simple pass             53             89                69.0
# 4    98.265191  Simple pass             42             55                36.0
# 8   130.656530    Head pass             34             91                52.0
# 11  161.221470  Simple pass             14             65                11.0
#
#     EventDestination_y
# 0                 95.0
# 1                 91.0
# 4                 54.0
# 8                 97.0
# 11                50.0

# %%
# 汇总计算，每个球员给其它球员传了多少次球
dataset = dataset.groupby(["OriginPlayerID", "DestinationPlayerID"]).size().reset_index(name='size')
dataset.head()
# Out:
#   OriginPlayerID DestinationPlayerID  size
# 0     Huskies_D1          Huskies_D2    14
# 1     Huskies_D1          Huskies_D3     8
# 2     Huskies_D1          Huskies_D4     1
# 3     Huskies_D1          Huskies_D5     3
# 4     Huskies_D1          Huskies_F1     3

# %% [markdown]
# ### 2. 构造Graph所需的nodes、links数据

# %%
# 所有去重后的队员ID
players = pd.concat([dataset["OriginPlayerID"], dataset["DestinationPlayerID"]]).unique()
players
# Out:
# array(['Huskies_D1', 'Huskies_D2', 'Huskies_D3', 'Huskies_D4',
#        'Huskies_D5', 'Huskies_F1', 'Huskies_F2', 'Huskies_F3',
#        'Huskies_G1', 'Huskies_M1', 'Huskies_M2', 'Huskies_M3',
#        'Huskies_M4', 'Huskies_M5'], dtype=object)

# %%
# 图所需的节点列表
nodes = []
for player in players:
    nodes.append({"name": player, "symbolSize": 10})
nodes[:3]
# Out:
# [{'name': 'Huskies_D1', 'symbolSize': 10},
#  {'name': 'Huskies_D2', 'symbolSize': 10},
#  {'name': 'Huskies_D3', 'symbolSize': 10}]

# %%
# 图所需要的边
links=[]
for index, row in dataset.iterrows():
    links.append({"source": row["OriginPlayerID"], 
                  "target": row["DestinationPlayerID"], 
                  "value": row["size"]})
links[:3]
# Out:
# [{'source': 'Huskies_D1', 'target': 'Huskies_D2', 'value': 14},
#  {'source': 'Huskies_D1', 'target': 'Huskies_D3', 'value': 8},
#  {'source': 'Huskies_D1', 'target': 'Huskies_D4', 'value': 1}]

# %% [markdown]
# ### 3. 使用Pyecharts绘制Graph图

# %%
graph = (
    Graph()
    .add("", 
        nodes,  # 节点列表
        links,  # 边列表
        repulsion=5000,   #节点之间的斥力因子，值越大则斥力越大
        edge_label=opts.LabelOpts(is_show=True, position="middle", formatter="{c}"), # 在边上显示数据
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="传球网络图"))
)

# %%
graph.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="226f32ad88284e71ac0179cacd4d73f4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_226f32ad88284e71ac0179cacd4d73f4 = echarts.init(
#                     document.getElementById('226f32ad88284e71ac0179cacd4d73f4'), 'white', {renderer: 'canvas'});
#                 var option_226f32ad88284e71ac0179cacd4d73f4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 5000,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "Huskies_D1",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_D2",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_D3",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_D4",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_D5",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_F1",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_F2",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_F3",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_G1",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_M1",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_M2",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_M3",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_M4",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "Huskies_M5",
#                     "symbolSize": 10
#                 }
#             ],
#             "edgeLabel": {
#                 "show": true,
#                 "position": "middle",
#                 "margin": 8,
#                 "formatter": "{c}"
#             },
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_D2",
#                     "value": 14
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_D3",
#                     "value": 8
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_D4",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_D5",
#                     "value": 3
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_F1",
#                     "value": 3
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_F2",
#                     "value": 3
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_F3",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_G1",
#                     "value": 2
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_M1",
#                     "value": 11
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_M2",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_M3",
#                     "value": 4
#                 },
#                 {
#                     "source": "Huskies_D1",
#                     "target": "Huskies_M4",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D2",
#                     "target": "Huskies_D1",
#                     "value": 11
#                 },
#                 {
#                     "source": "Huskies_D2",
#                     "target": "Huskies_D3",
#                     "value": 18
#                 },
#                 {
#                     "source": "Huskies_D2",
#                     "target": "Huskies_F1",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D2",
#                     "target": "Huskies_F2",
#                     "value": 3
#                 },
#                 {
#                     "source": "Huskies_D2",
#                     "target": "Huskies_G1",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D2",
#                     "target": "Huskies_M1",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D2",
#                     "target": "Huskies_M3",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D3",
#                     "target": "Huskies_D1",
#                     "value": 6
#                 },
#                 {
#                     "source": "Huskies_D3",
#                     "target": "Huskies_D2",
#                     "value": 6
#                 },
#                 {
#                     "source": "Huskies_D3",
#                     "target": "Huskies_D4",
#                     "value": 9
#                 },
#                 {
#                     "source": "Huskies_D3",
#                     "target": "Huskies_F1",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D3",
#                     "target": "Huskies_F2",
#                     "value": 2
#                 },
#                 {
#                     "source": "Huskies_D3",
#                     "target": "Huskies_F3",
#                     "value": 1
#                 },
#                 {
#                     "source": "Huskies_D3",

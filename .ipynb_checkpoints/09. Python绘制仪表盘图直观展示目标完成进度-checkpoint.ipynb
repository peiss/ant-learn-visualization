# %% [markdown]
# ## Python绘制仪表盘图直观展示目标完成进度

# %% [markdown]
# 仪表盘（Gauge）：
# * BI仪表盘的标配大图（business intelligence dashboard，BI dashboard）
# * 通过百分比指针，直观的展示目标的完成进度，比如收入/营业额目标进度

# %%
import pyecharts

# %%
pyecharts.__version__
# Out:
# '1.7.1'

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge

# %% [markdown]
# ### 1. 绘制单指针仪表盘

# %%
gauge = (
    Gauge()
    .add("业务指标", [("收入完成率", 87.8)])
    .set_global_opts(title_opts=opts.TitleOpts(title="收入完成率"))
)

# %%
gauge.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c86baf840aac4ee18a5d155fb70bb214" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c86baf840aac4ee18a5d155fb70bb214 = echarts.init(
#                     document.getElementById('c86baf840aac4ee18a5d155fb70bb214'), 'white', {renderer: 'canvas'});
#                 var option_c86baf840aac4ee18a5d155fb70bb214 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u6536\u5165\u5b8c\u6210\u7387",
#                     "value": 87.8
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6536\u5165\u5b8c\u6210\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c86baf840aac4ee18a5d155fb70bb214.setOption(option_c86baf840aac4ee18a5d155fb70bb214);
#         });
#     </script>

# %% [markdown]
# ### 2. 绘制多指针仪表盘

# %%
gauge = (
    Gauge()
    .add("业务指标", [("上衣营业额", 90.5), ("裤子营业额", 39.4), ("鞋子营业额", 15.8)])
    .set_global_opts(title_opts=opts.TitleOpts(title="收入完成率"))
)

# %%
gauge.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e340bb9d7e1b4256894bf90fdbb44d6f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e340bb9d7e1b4256894bf90fdbb44d6f = echarts.init(
#                     document.getElementById('e340bb9d7e1b4256894bf90fdbb44d6f'), 'white', {renderer: 'canvas'});
#                 var option_e340bb9d7e1b4256894bf90fdbb44d6f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u4e0a\u8863\u8425\u4e1a\u989d",
#                     "value": 90.5
#                 },
#                 {
#                     "name": "\u88e4\u5b50\u8425\u4e1a\u989d",
#                     "value": 39.4
#                 },
#                 {
#                     "name": "\u978b\u5b50\u8425\u4e1a\u989d",
#                     "value": 15.8
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6536\u5165\u5b8c\u6210\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_e340bb9d7e1b4256894bf90fdbb44d6f.setOption(option_e340bb9d7e1b4256894bf90fdbb44d6f);
#         });
#     </script>
